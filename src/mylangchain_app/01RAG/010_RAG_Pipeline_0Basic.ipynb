# %% [markdown]
# ## 0. 환경 구성

# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add langchain_community faiss-cpu

# %% [markdown]
# ### 2) OpenAI 인증키 설정
# https://openai.com/

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_b

# %%
EMBEDDING_MODEL_NAME = "bge-m3:latest"
EMBEDDING_MODEL_NAME
# Out:
# 'bge-m3:latest'

# %% [markdown]
# #### RAG 파이프 라인
# * Load Data - Text Split - Indexing - Retrieval - Generation
# * OllamaEmbeddings 사용

# %%
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. Load Data
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

print(type(documents), len(documents)) #[Documentm, Document]
print(type(documents[0]))
#print(documents[0])
# Out:
# <class 'list'> 1
# <class 'langchain_core.documents.base.Document'>

# %%
# 2️. Text Split
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
split_docs = splitter.split_documents(documents)

print(len(split_docs), type(split_docs))
print(split_docs[0])
print('두번째 Document ====================')
print(split_docs[1])
# Out:
# 12 <class 'list'>
# page_content='제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 20., 2018. 3. 20., 2018. 12. 31., 2019. 12. 10., 2019. 12. 31., 2020. 6. 9., 2020. 12. 29., 2022. 8. 12., 2022. 12. 31., 2023. 8. 8., 2023. 12. 31.>
# 1. 「공익신탁법」에 따른 공익신탁의 이익
# 2. 사업소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득' metadata={'source': '../data/taxinfo.txt'}
# 두번째 Document ====================
# page_content='가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득
#     나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.
#     다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양도로 발생하는 소득으로서 연 600만원 이하의 금액. 이 경우 조림기간 및 세액의 계산 등 필요한 사항은 대통령령으로 정한다.
#     바. 대통령령으로 정하는 작물재배업에서 발생하는 소득' metadata={'source': '../data/taxinfo.txt'}

# %%
# 3️. Indexing (벡터 저장)
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)
#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())

# 로컬 파일로 저장
vectorstore.save_local("faiss_index")

# %%
# 4️. Retrieval (유사 문서 검색) k: 질의와 가장 유사한 문서(청크) 6개를 찾아 반환하기
retriever = vectorstore.as_retriever(search_kwargs={"k": 6})
print(type(retriever))
# **질문(쿼리)**에 대해 유사한 문서를 검색하는 역할
retrieved_docs = retriever.invoke("소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?")
print(type(retrieved_docs), len(retrieved_docs))
print(type(retrieved_docs[0]))
print(retrieved_docs[0])
# Out:
# <class 'langchain_core.vectorstores.base.VectorStoreRetriever'>
# <class 'list'> 6
# <class 'langchain_core.documents.base.Document'>
# page_content='제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 20., 2018. 3. 20., 2018. 12. 31., 2019. 12. 10., 2019. 12. 31., 2020. 6. 9., 2020. 12. 29., 2022. 8. 12., 2022. 12. 31., 2023. 8. 8., 2023. 12. 31.>
# 1. 「공익신탁법」에 따른 공익신탁의 이익
# 2. 사업소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득' metadata={'source': '../data/taxinfo.txt'}

# %%
# 5️. Generation (LLM 응답 생성)
#llm = ChatOpenAI(model="gpt-4o-mini")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)

context = "\n\n".join([doc.page_content for doc in retrieved_docs])
print(context)
# Out:
# 제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 20., 2018. 3. 20., 2018. 12. 31., 2019. 12. 10., 2019. 12. 31., 2020. 6. 9., 2020. 12. 29., 2022. 8. 12., 2022. 12. 31., 2023. 8. 8., 2023. 12. 31.>
# 1. 「공익신탁법」에 따른 공익신탁의 이익
# 2. 사업소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득
#
# 가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득
#     나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.
#     다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양도로 발생하는 소득으로서 연 600만원 이하의 금액. 이 경우 조림기간 및 세액의 계산 등 필요한 사항은 대통령령으로 정한다.
#     바. 대통령령으로 정하는 작물재배업에서 발생하는 소득
#
# 바. 대통령령으로 정하는 작물재배업에서 발생하는 소득
#     사. 대통령령으로 정하는 어로어업 또는 양식어업에서 발생하는 소득
# 3. 근로소득과 퇴직소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 대통령령으로 정하는 복무 중인 병(兵)이 받는 급여
#     나. 법률에 따라 동원된 사람이 그 동원 직장에서 받는 급여
#     다. 「산업재해보상보험법」에 따라 수급권자가 받는 요양급여, 휴업급여, 장해급여, 간병급여, 유족급여, 유족특별급여, 장해특별급여, 장의비 또는 근로의 제공으로 인한 부상ㆍ질병ㆍ사망과 관련하여 근로자나 그 유족이 받는 배상ㆍ보상 또는 위자(慰藉)의 성질이 있는 급여
#     라. 「근로기준법」 또는 「선원법」에 따라 근로자ㆍ선원 및 그 유족이 받는 요양보상금, 휴업보상금, 상병보상금(傷病補償金), 일시보상금, 장해보상금, 유족보상금, 행방불명보상금, 소지품 유실보상금, 장의비 및 장제비
#
# 아. 제21조제1항제26호에 따른 종교인소득 중 다음의 어느 하나에 해당하는 소득
#     　　　　1) 「통계법」 제22조에 따라 통계청장이 고시하는 한국표준직업분류에 따른 종교관련종사자(이하 “종교관련종사자”라 한다)가 받는 대통령령으로 정하는 학자금
#     　　　　2) 종교관련종사자가 받는 대통령령으로 정하는 식사 또는 식사대
#     　　　　3) 종교관련종사자가 받는 대통령령으로 정하는 실비변상적 성질의 지급액
#     　　　　4) 종교관련종사자 또는 그 배우자의 출산이나 6세 이하(해당 과세기간 개시일을 기준으로 판단한다) 자녀의 보육과 관련하여 종교단체로부터 받는 금액으로서 월 20만원 이내의 금액
#     　　　　5) 종교관련종사자가 기획재정부령으로 정하는 사택을 제공받아 얻는 이익
#     자. 법령ㆍ조례에 따른 위원회 등의 보수를 받지 아니하는 위원(학술원 및 예술원의 회원을 포함한다) 등이 받는 수당
#
# 나. 삭제<2013. 1. 1.>
#     다. 「산업재해보상보험법」에 따라 받는 각종 연금
#     라. 「국군포로의 송환 및 대우 등에 관한 법률」에 따른 국군포로가 받는 연금
#     마. 삭제<2013. 1. 1.>
# 5. 기타소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 「국가유공자 등 예우 및 지원에 관한 법률」 또는 「보훈보상대상자 지원에 관한 법률」에 따라 받는 보훈급여금ㆍ학습보조비 및 「북한이탈주민의 보호 및 정착지원에 관한 법률」에 따라 받는 정착금ㆍ보로금(報勞金)과 그 밖의 금품
#     나. 「국가보안법」에 따라 받는 상금과 보로금
#     다. 「상훈법」에 따른 훈장과 관련하여 받는 부상(副賞)이나 그 밖에 대통령령으로 정하는 상금과 부상
#
# 라. 종업원등 또는 대학의 교직원이 퇴직한 후에 사용자등 또는 산학협력단으로부터 지급받거나 대학의 학생이 소속 대학에 설치된 산학협력단으로부터 받는 직무발명보상금으로서 대통령령으로 정하는 금액. 다만, 직무발명보상금을 지급한 사용자등 또는 산학협력단과 대통령령으로 정하는 특수관계에 있는 자가 받는 직무발명보상금은 제외한다.
#     마. 「국군포로의 송환 및 대우 등에 관한 법률」에 따라 국군포로가 받는 위로지원금과 그 밖의 금품
#     바. 「문화유산의 보존 및 활용에 관한 법률」에 따라 국가지정문화유산으로 지정된 서화ㆍ골동품의 양도로 발생하는 소득
#     사. 서화ㆍ골동품을 박물관 또는 미술관에 양도함으로써 발생하는 소득
#     아. 제21조제1항제26호에 따른 종교인소득 중 다음의 어느 하나에 해당하는 소득

# %%
response_context = llm.invoke(f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요? 관련 정보: {context}")
print('context 적용한 결과')
pprint(response_context.content)

response = llm.invoke(f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?")
print('context 적용하지 않은 결과')
pprint(response.content)
# Out:
# context 적용한 결과
# ('소득세법 제12조(비과세소득)에 따라 소득세를 부과하지 아니하는 「비과세소득」은 다음과 같습니다. (2023. 12. 31. 현행 조문 '
#  '기준 요약)\n'
#  '\n'
#  '### 1. 공익신탁 이익  \n'
#  '- 「공익신탁법」에 따른 공익신탁으로부터 나오는 모든 이익\n'
#  '\n'
#  '### 2. 사업소득 가운데  \n'
#  '- 농지(논·밭)를 타인에게 작물 생산용으로 넘겨 얻는 소득  \n'
#  '- 1주택 임대소득(시가 12억 초과·국외주택 제외) 또는 1년 총수입 2천만원 이하 임대소득(2018 과세기한까지)  \n'
#  '- 대통령령이 정하는 농어가(農漁家) 부업소득  \n'
#  '- 전통주 제조소득(대통령령 기준)  \n'
#  '- 조림 5년 이상 임지의 임목 벌채·양도소득(연 600만원 한도)  \n'
#  '- 대통령령이 정하는 작물재배업·어로·양식어업 소득\n'
#  '\n'
#  '### 3. 근로·퇴직소득 가운데  \n'
#  '- 병역 복무 중 병사 급여  \n'
#  '- 법령에 의한 동원근로 급여  \n'
#  '- 산재보험·근기법·선원법에 따른 요양·휴업·장해·유족·장의비 등 보상금·급여  \n'
#  '- 종교인소득 중 학자금·식사·실비변상적 급여, 출산·보육지원비(월 20만원 한도), 사택 제공 이익  \n'
#  '- 위원회 위원 등이 보수 없이 활동하면서 받는 수당(법령·조례 기준)  \n'
#  '- 「산업재해보상보험법」 각종 연금·국군포로연금\n'
#  '\n'
#  '### 4. 기타소득 가운데  \n'
#  '- 국가유공자·보훈·북한이탈주민 보훈급여·정착금·보로금  \n'
#  '- 국가보안법·상훈법에 따른 상금·보로금·부상  \n'
#  '- 퇴직 후 직무발명보상금(대통령령 한도, 특수관계자 제외)  \n'
#  '- 국군포로 위로지원금  \n'
#  '- 국지정문화유산(서화·골동품) 양도소득, 박물관·미술관 양도소득  \n'
#  '- 종교인소득 중 대통령령으로 정하는 식사·실비변상·보육지원·사택이익 등\n'
#  '\n'
#  '※ 위 항목은 모두 법 조문에 ‘대통령령으로 정하는’ 요건이 붙은 경우가 많으므로, 구체적인 적용 여부는 해당 시행령(소득세법 시행령)과 '
#  '최근 국세청·기재부 고시를 반드시 확인해야 합니다.')
# context 적용하지 않은 결과
# ('소득세법에서 **비과세소득**은 말 그대로 **소득세를 부과하지 않는 소득**을 말합니다.  \n'
#  '다음은 소득세법 및 관련 법령에 따라 **비과세로 규정된 주요 소득**입니다.  \n'
#  '(※ 아래는 2025년 1월 기준 주요 항목이며, 일부는 한도나 조건이 있습니다.)\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 주요 비과세소득 요약\n'
#  '\n'
#  '| 소득 유형 | 비과세 내용 | 관련 법조 |\n'
#  '|-----------|-------------|------------|\n'
#  '| **공로급여** | 국가유공자 등에게 지급하는 공로금, 위로금 등 | 소법 §12①①호 |\n'
#  '| **보훈급여** | 국가유공자 및 유족에게 지급하는 보훈금, 연금 등 | 소법 §12①②호 |\n'
#  '| **재해보상금** | 재해·재난으로 인한 보상금, 구호금 등 | 소법 §12①③호 |\n'
#  '| **생활보조금** | 기초생활수급자 등에게 지급하는 급여, 장애인연금 등 | 소법 §12①④호 |\n'
#  '| **국민기초연금** | 기초연금(노령연금) | 소법 §12①⑤호 |\n'
#  '| **장학금** | 대학생 등에게 지급하는 장학금(일정 한도 내) | 소법 §12①⑥호 |\n'
#  '| **출산·육아급여** | 출산축하금, 육아수당 등 | 소법 §12①⑦호 |\n'
#  '| **이사비용** | 실비변상 형태의 이사비용 | 소법 §12①⑧호 |\n'
#  '| **근로자복지기금** | 복지기금에서 지급하는 금품(일정 조건) | 소법 §12①⑨호 |\n'
#  '| **증여·상속재산** | 증여세·상속세 대상 재산 | 소법 §12①⑩호 |\n'
#  '| **보험금** | 생명·상해보험금(일정 조건) | 소법 §12①⑪호 |\n'
#  '| **국가보훈처 급여** | 보훈급여, 보훈연금 등 | 소법 §12①⑫호 |\n'
#  '| **외교관 등 급여** | 외교관, 국제기구 직원 급여 | 소법 §12①⑬호 |\n'
#  '| **종교인 소득** | 종교활동에 따른 소득(일정 한도) | 소법 §12①⑭호 |\n'
#  '| **농어촌특별세 감면** | 농어촌 소득(일정 조건) | 소법 §12①⑮호 |\n'
#  '| **가상자산 이전소득** | 1회 200만원 이하, 연 400만원 이하 | 소법 §12①⑯호 (2023년 신설) |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 📌 참고\n'
#  '- **조건이나 한도**가 있는 경우가 많습니다. 예: 장학금은 **연간 600만원 이하**, 종교인 소득은 **월 300만원 이하** '
#  '등.\n'
#  '- **비과세 한도 초과분**은 **과세 대상**이 됩니다.\n'
#  '- **법인이 지급하는 경우**에도 개인에게 비과세될 수 있으나, **지급 근거와 증빙**이 중요합니다.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '필요하시면 **특정 항목**에 대해 더 자세히 알려드릴 수 있어요.')

# %% [markdown]
# ### 개선한 Source - version1
# * Retriever 검색방법 개선
#     * search_type="mmr",  # 최대 다양성 검색
#     * search_kwargs={"k": 6, "fetch_k": 10}

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. 데이터 로드 (기존과 동일)
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

# 2. 텍스트 분할 개선
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # 크기 증가
    chunk_overlap=200,
    separators=["\n\n", "\n", " ", ""],  # 자연스러운 분할을 위한 구분자
    length_function=len,
    is_separator_regex=False,
)
split_docs = splitter.split_documents(documents)

# 3. 인덱싱 (벡터 저장)
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)
#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())

vectorstore.save_local("faiss_index")

# 4. 검색 개선
"""
    최대 다양성 검색(Maximum Marginal Relevance, MMR)
    MMR은 유사도가 높은 문서를 찾는 것을 넘어, 유사도와 다양성이라는 두 가지 기준을 모두 고려함
    - search_type="mmr": 검색 방식을 MMR로 지정합니다.
    - fetch_k: 일차적으로 질의와 유사한 문서 10개를 벡터 저장소에서 가져옵니다.
    - k: fetch_k로 가져온 10개의 문서 중에서 최종적으로 6개를 선택합니다. 6개를 선택할 때, MMR 알고리즘은 다음 두 가지를 고려함
        : 질의와의 유사도가 높고, 이미 선택된 다른 문서들과의 유사도가 낮은 (즉, 내용이 다양한) 문서
    * MMR의 작동 원리:
    - 질의와 가장 유사한 fetch_k개(10개)의 문서를 예비 후보군으로 가져옵니다.
    - 이 후보군 중에서 질의와 가장 유사한 문서 하나를 첫 번째 결과로 선택합니다.
    - 남은 후보군 중에서 질의와의 유사도는 높으면서 (관련성), 
      이미 선택된 문서들과의 유사도는 낮은 (다양성) 문서를 찾아 다음 결과로 추가함
    - 이 과정을 k개(6개)의 문서가 모두 선택될 때까지 반복합니다.        
"""
retriever = vectorstore.as_retriever(
    search_type="mmr",  # 최대 다양성 검색
    search_kwargs={"k": 6, "fetch_k": 10}  # 더 많은 결과 검색
)

# 5. 프롬프트 엔지니어링
def generate_prompt(query, context):
    return f"""다음은 소득세법 비과세소득 관련 조항입니다. 문맥을 고려하여 질문에 답변하세요.

[관련 조항]
{context}

[질문]
{query}

[답변 요구사항]
- 비과세소득 유형을 계층적으로 구분하여 설명
- 각 항목별 구체적인 조건 명시
- 법조문의 항, 호, 목 번호를 포함
- 500자 이내로 간결하게 요약"""

# 검색 및 응답 생성
query = "소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?"
retrieved_docs = retriever.invoke(query)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])

#llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)  # 창의성 낮춤
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
response = llm.invoke(generate_prompt(query, context))

print('개선된 결과:')
pprint(response.content)
# Out:
# 개선된 결과:
# ('소득세법 제12조 비과세소득은 5계층으로 구분된다.\n'
#  '\n'
#  '1. 공익신탁 이익(제12조제1호)\n'
#  '\n'
#  '2. 사업소득(제12조제2호)\n'
#  '- 논·밭 작물생산 소득(가목)\n'
#  '- 1주택(기준시가 12억 이하) 임대소득 또는 연 2천만원 이하 주택임대소득(나목, 2018과세기한)\n'
#  '- 농어가부업·전통주제조·작물재배·어로·양식어업 소득(다·라·바·사목)\n'
#  '- 5년 이상 조림지 벌채·양도소득 연 600만원 이하(마목)\n'
#  '\n'
#  '3. 근로·퇴직소득(제12조제3호)\n'
#  '- 종업원 직무발명보상금(1호)\n'
#  '- 대학 산학협력단 보상금(2호)\n'
#  '- 복리후생적 급여(저호)\n'
#  '\n'
#  '4. 연금소득(제12조제4호)\n'
#  '공적연금 관련법 유족·장애·상이연금 등, 산재보험·국군포로연금\n'
#  '\n'
#  '5. 기타소득(제12조제5호)\n'
#  '보훈급여, 국가보안법 상금, 훈장부상, 퇴직후 직무발명보상금, 국군포로위로금, 문화재 양도소득, 종교인 학자금·식사대·실비변상·보육비(월 '
#  '20만원)·사택이익, 위원수당 등')

# %% [markdown]
# ### 개선한 Source - version2
# * Prompt 개선

# %%
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. Load Data
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

print("=== 원본 문서 길이 ===")
print(f"전체 문서 길이: {len(documents[0].page_content)} 글자")

# 2. Text Split 개선
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,  
    chunk_overlap=150,
    separators=["\n\n", "\n", ". ", " ", ""]  # 법령 구조에 맞는 분리자
)
split_docs = splitter.split_documents(documents)

print(f"분할된 문서 수: {len(split_docs)}개")
print("=== 분할 예시 ===")
for i, doc in enumerate(split_docs[:3]):
    print(f"Chunk {i+1} ({len(doc.page_content)}글자): {doc.page_content[:100]}...")

# 3. Indexing
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)

#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())
vectorstore.save_local("faiss_index")

# 4. Retrieval 개선
retriever = vectorstore.as_retriever(
    search_type="similarity", 
    search_kwargs={"k": 6}  
)

query = "소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?"
retrieved_docs = retriever.invoke(query)

print(f"\n=== 검색된 문서 ({len(retrieved_docs)}개) ===")
for i, doc in enumerate(retrieved_docs):
    print(f"문서 {i+1}: {doc.page_content[:200]}...")
    print("---")

# 5. Generation - 개선된 프롬프트
#llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
context = "\n\n".join([f"[문서 {i+1}]\n{doc.page_content}" for i, doc in enumerate(retrieved_docs)])

# 개선된 프롬프트 - 더 구체적인 지시사항
improved_prompt = f"""
당신은 세무 전문가입니다. 아래 소득세법 제12조 조항을 바탕으로 질문에 답변해주세요.

질문: {query}

법령 조항:
{context}

다음 형식으로 답변해주세요:
1. 비과세소득의 정의
2. 주요 비과세소득 항목들을 다음과 같이 분류:
   - 사업소득 관련
   - 근로소득/퇴직소득 관련  
   - 연금소득 관련
   - 기타소득 관련
3. 각 항목별 구체적인 조건이나 한도액 명시

답변은 법조문을 인용하면서 구체적으로 작성해주세요.
"""

# 비교용 - 기존 방식
simple_prompt = f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요? 관련 정보: {context}"

print("\n=== 개선된 프롬프트로 답변 ===")
response_improved = llm.invoke(improved_prompt)
pprint(response_improved.content)

print("\n" + "="*50)
print("=== 기존 프롬프트로 답변 ===")
response_simple = llm.invoke(simple_prompt)
pprint(response_simple.content)
# Out:
# === 원본 문서 길이 ===
# 전체 문서 길이: 4971 글자
# 분할된 문서 수: 8개
# === 분할 예시 ===
# Chunk 1 (738글자): 제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2....
# Chunk 2 (636글자): 다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양...
# Chunk 3 (792글자): 라. 「근로기준법」 또는 「선원법」에 따라 근로자ㆍ선원 및 그 유족이 받는 요양보상금, 휴업보상금, 상병보상금(傷病補償金), 일시보상금, 장해보상금, 유족보상금, 행방불명보상금, ...
#
# === 검색된 문서 (6개) ===
# 문서 1: 제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 2...
# ---
# 문서 2: 다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양도로 발생하는 소득으로서 연 600만원 이하의 금액. 이 경우 조림기간 및 세액의 계산 등 필요한 사항은 대통령령으로 정한다.
#     바. 대통령령으로 정하는 작물재배업에서 발생하...
# ---
# 문서 3: 나. 「국가보안법」에 따라 받는 상금과 보로금
#     다. 「상훈법」에 따른 훈장과 관련하여 받는 부상(副賞)이나 그 밖에 대통령령으로 정하는 상금과 부상
#     라. 종업원등 또는 대학의 교직원이 퇴직한 후에 사용자등 또는 산학협력단으로부터 지급받거나 대학의 학생이 소속 대학에 설치된 산학협력단으로부터 받는 직무발명보상금으로서 대통령령으로 정하는 금액. ...
# ---
# 문서 4: 4) 종교관련종사자 또는 그 배우자의 출산이나 6세 이하(해당 과세기간 개시일을 기준으로 판단한다) 자녀의 보육과 관련하여 종교단체로부터 받는 금액으로서 월 20만원 이내의 금액
#     　　　　5) 종교관련종사자가 기획재정부령으로 정하는 사택을 제공받아 얻는 이익
#     자. 법령ㆍ조례에 따른 위원회 등의 보수를 받지 아니하는 위원(학술원 및 예술원의 회원...
# ---
# 문서 5: 2) 대학의 교직원 또는 대학과 고용관계가 있는 학생이 소속 대학에 설치된 「산업교육진흥 및 산학연협력촉진에 관한 법률」 제25조에 따른 산학협력단(이하 이 조에서 “산학협력단”이라 한다)으로부터 같은 법 제32조제1항제4호에 따라 받는 보상금
#     저. 대통령령으로 정하는 복리후생적 성질의 급여
# 4. 연금소득 중 다음 각 목의 어느 하나에 해당하는 소득...
# ---
# 문서 6: 더. 생산직 및 그 관련 직에 종사하는 근로자로서 급여 수준 및 직종 등을 고려하여 대통령령으로 정하는 근로자가 대통령령으로 정하는 연장근로ㆍ야간근로 또는 휴일근로를 하여 받는 급여
#     러. 근로자가 사내급식이나 이와 유사한 방법으로 제공받는 식사 기타 음식물 또는 근로자(식사 기타 음식물을 제공받지 아니하는 자에 한정한다)가 받는 월 20만원 이하의 ...
# ---
#
# === 개선된 프롬프트로 답변 ===
# ('1. 비과세소득의 정의  \n'
#  '소득세법 제12조는 “다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다”고 규정하면서, 소득의 성격·목적·사회정책적 고려 등에 '
#  '따라 일정 소득을 세법상 전면 또는 조건부로 비과세(非課稅)한다.\n'
#  '\n'
#  '2. 주요 비과세소득 항목(분류)  \n'
#  '가. 사업소득 관련  \n'
#  '① 「공익신탁법」에 따른 공익신탁 이익(제12조 제1호)  \n'
#  '② 논·밭을 작물 생산에 이용하게 함으로써 발생하는 소득(제12조 제2호 가목)  \n'
#  '③ 1주택자의 주택임대소득  \n'
#  '  – 제99조 기준시가 12억원 이하 국내 1주택  \n'
#  '  – 과세기간 총수입 2천만원 이하(2018. 12. 31.까지 끝나는 과세기간 한정)  \n'
#  '④ 대통령령이 정하는 농어가부업소득(제12조 제2호 다목)  \n'
#  '⑤ 대통령령이 정하는 전통주 제조소득(제12조 제2호 라목)  \n'
#  '⑥ 조림기간 5년 이상 임지의 임목 벌채·양도소득  \n'
#  '  – 연 600만원 이하 한도(제12호 제2호 마목)  \n'
#  '⑦ 대통령령이 정하는 작물재배업·어로·양식어업 소득(제12조 제2호 바목, 사목)\n'
#  '\n'
#  '나. 근로소득·퇴직소득 관련  \n'
#  '① 복무 중 병(兵)이 받는 급여(제12조 제3호 가목)  \n'
#  '② 법률에 따라 동원된 사람이 그 직장에서 받는 급여(제12조 제3호 나목)  \n'
#  '③ 「산업재해보상보험법」상 요양·휴업·장해·간병·유족·장의비 등(제12조 제3호 다목)  \n'
#  '④ 「근로기준법」·「선원법」상 보상금·장의비 등(제12조 제3호 라목)  \n'
#  '⑤ 「국군포로의 송환 및 대우 등에 관한 법률」에 따른 보수·퇴직일시금(제12조 제6호 버목)  \n'
#  '⑥ 장학금 중 대학생이 근로 대가로 받는 장학금(「교육기본법」 제28조제1항, 제12조 제6호 서목)  \n'
#  '⑦ 직무발명보상금(「발명진흥법」)으로서 대통령령이 정하는 금액(제12조 제6호 어목)  \n'
#  '⑧ 복리후생적 급여로서 대통령령이 정하는 것(제12조 제6호 저목)  \n'
#  '⑨ 연장·야간·휴일근로 수당 중 대통령령이 정하는 생산직 근로자 급여(제12조 제6호 더목)  \n'
#  '⑩ 사내급식·식사대  \n'
#  '  – 급식 실물제공, 또는  \n'
#  '  – 급식을 제공받지 못하는 자가 받는 월 20만원 이하 식사대(제12조 제6호 러목)  \n'
#  '⑪ 출산·보육 관련 급여  \n'
#  '  – 근로자(또는 배우자) 출산·6세 이하 자녀 보육목적  \n'
#  '  – 월 20만원 한도(제12조 제6호 머목)\n'
#  '\n'
#  '다. 연금소득 관련  \n'
#  '① 공적연금(국민·공무원·군인·사립학교·별정우체국 등) 유족·장해·장애·상이·순직·위험직무순직·연계노령유족연금 등(제12조 제4호 '
#  '가목)  \n'
#  '② 「산업재해보상보험법」상 각종 연금(제12조 제4호 다목)  \n'
#  '③ 「국군포로의 송환 및 대우 등에 관한 법률」에 따른 국군포로 연금(제12조 제4호 라목)\n'
#  '\n'
#  '라. 기타소득 관련  \n'
#  '① 「국가유공자 등 예우 및 지원에 관한 법률」「보훈보상대상자 지원에 관한 법률」상 보훈급여금·학습보조비(제12조 제5호 가목)  \n'
#  '② 「북한이탈주민의 보호 및 정착지원에 관한 법률」상 정착금·보로금 등(제12조 제5호 가목)  \n'
#  '③ 「국가보안법」에 따른 상금·보로금(제12조 제5호 나목, 제3호 나목)  \n'
#  '④ 「국가보안법」상 상금·보로금(제12조 제3호 나목)  \n'
#  '⑤ 「상훈법」에 따른 훈장 부상(副賞), 상금 등(제12조 제3호 다목)  \n'
#  '⑥ 종업원등·대학교직원 퇴직 후 산학협력단 직무발명보상금(특수관계인 제외, 제12조 제3호 라목)  \n'
#  '⑦ 「문화유산보존법」상 국가지정문화유산(서화·골동품) 양도소득(제12조 제3호 바목)  \n'
#  '⑧ 박물관·미술관에 서화·골동품 양도로 발생하는 소득(제12조 제3호 사목)  \n'
#  '⑨ 종교인소득 중  \n'
#  '  – 통계청 고시 종교관련종사자가 받는 대통령령이 정하는 학자금·식사(대)·실비변상적 지급액  \n'
#  '  – 출산·6세 이하 자녀 보육목적 종교단체 지급금 월 20만원 한도(제12조 제3호 아목)  \n'
#  '⑩ 법령·조례 위원회 등에서 보수를 받지 않는 위원(학술원·예술원 회원 포함)이 받는 수당(제12조 제3호 자목)\n'
#  '\n'
#  '3. 각 항목별 주요 한도·조건 요약  \n'
#  '- 1주택 임대소득 : 기준시가 12억원 이하, 국내 1주택, 과세기간 총수입 2천만원 이하(2018과세기간까지)  \n'
#  '- 임목 양도 : 조림 5년 이상, 연 600만원 이하  \n'
#  '- 식사대 : 월 20만원 이하  \n'
#  '- 출산·보육급여(근로자·종교인 공통) : 월 20만원 한도, 6세 이하 자녀 기준  \n'
#  '- 직무발명보상금 : 대통령령이 정하는 금액 한도, 지급주체와 특수관계인은 제외  \n'
#  '- 장학금(근로대가형) : 「고등교육법」상 대학 재학생에 한함  \n'
#  '- 연금 비과세 : 공적연금·산재보험·국군포로연금 등 법률에 따라 지급되는 연금 중 법에서 명시한 유형만 해당\n'
#  '\n'
#  '이상이 소득세법 제12조가 정하고 있는 주요 비과세소득과 그 한도·조건입니다.')
#
# ==================================================
# === 기존 프롬프트로 답변 ===
# ('소득세법 제12조에 따르면, **비과세소득**은 총 5가지 큰 유형으로 나뉘며, 각 유형에 따라 다음과 같은 소득이 **소득세를 부과하지 '
#  '않는 비과세소득**에 해당합니다:\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 1. **공익신탁 소득**\n'
#  '- 「공익신탁법」에 따른 **공익신탁의 이익**\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 2. **사업소득 중 비과세 대상**\n'
#  '- **논·밭을 작물 생산에 이용하게 함으로써 발생하는 소득**\n'
#  '- **1주택 임대소득** (단, 기준시가 12억원 이하 주택에 한함)\n'
#  '- **연 총수입 2천만원 이하 주택임대소득** (2018년 이전 분에 한정)\n'
#  '- **농어가부업소득** (대통령령으로 정함)\n'
#  '- **전통주 제조 소득**\n'
#  '- **조림 5년 이상 임지의 임목 벌채·양도 소득** (연 600만원 이하)\n'
#  '- **작물재배업 소득**\n'
#  '- **어로·양식어업 소득**\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 3. **근로·퇴직소득 중 비과세 대상**\n'
#  '- **현역 병사의 급여**\n'
#  '- **법률에 따라 동원된 사람의 급여**\n'
#  '- **산재보험 급여** (요양급여, 휴업급여, 장해급여 등)\n'
#  '- **근로기준법·선원법에 따른 보상금** (유족보상금, 장해보상금 등)\n'
#  '- **야간·연장·휴일근로 수당** (일부 대상자에 한정)\n'
#  '- **식사대 또는 식사 제공**\n'
#  '- **출산·보육 관련 급여** (월 20만원 이하)\n'
#  '- **직무발명보상금** (일정 조건 충족 시)\n'
#  '- **장학금 중 근로장학금** (대학생 한정)\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 4. **연금소득 중 비과세 대상**\n'
#  '- **공적연금 유족연금·장해연금·상이연금 등**\n'
#  '- **산재보험 연금**\n'
#  '- **국군포로 연금**\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 5. **기타소득 중 비과세 대상**\n'
#  '- **보훈급여금** (국가유공자 등)\n'
#  '- **정착금·보로금** (북한이탈주민)\n'
#  '- **상금·보로금** (국가보안법에 따른 것)\n'
#  '- **훈장 부상금**\n'
#  '- **문화재 양도 소득** (국가지정문화재 or 박물관·미술관 양도)\n'
#  '- **종교인 소득 중 일정 금액 이하의 학자금·식사대·보육비·사택 제공 이익 등**\n'
#  '- **위원 수당** (보수를 받지 않는 위원 등)\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 📌 요약\n'
#  '소득세법상 **비과세소득**은 **공익목적, 사회보장, 농어업 지원, 국가보훈, 종교·문화 활동 등 공공성이 높은 소득**을 중심으로 '
#  '**세금을 부과하지 않도록 규정**하고 있습니다.')

# %%
# 추가 개선: 다른 검색 방식 시도
print("\n" + "="*50)
print("=== 검색 방식 개선 테스트 ===")

# MMR(Maximum Marginal Relevance) 검색 - 다양성 확보
retriever_mmr = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={"k": 6, "fetch_k": 20}
)
retrieved_docs_mmr = retriever_mmr.invoke(query)
context_mmr = "\n\n".join([f"[문서 {i+1}]\n{doc.page_content}" for i, doc in enumerate(retrieved_docs_mmr)])

response_mmr = llm.invoke(f"""
{query}

법령 조항 (MMR 검색):
{context_mmr}

위 법령을 바탕으로 비과세소득 항목들을 체계적으로 정리해주세요.
""")

print("=== MMR 검색 결과 ===")
pprint(response_mmr.content)
# Out:
# ==================================================
# === 검색 방식 개선 테스트 ===
# === MMR 검색 결과 ===
# ('소득세법 제12조에 따른 ‘비과세소득’은  \n'
#  '“소득의 종류 → 세부 항목 → 법적 근거(특례·한도 등)”  \n'
#  '3단 구조로 정리하면 다음과 같습니다.\n'
#  '\n'
#  '------------------------------------------------\n'
#  '1. 사업소득\n'
#  '1.1 농업·임업·어업 관련  \n'
#  '- 논·밭을 작물 생산에 이용한 임대소득  \n'
#  '- 조림 5년 이상 임지의 임목 벌채·양도소득(연 600만원 이하)  \n'
#  '- 대통령령이 정하는 농어가부업소득  \n'
#  '- 전통주 제조소득(대통령령이 정하는 범위)  \n'
#  '- 작물재배업·어로·양식어업 소득(대통령령이 정하는 범위)\n'
#  '\n'
#  '1.2 주택임대소득  \n'
#  '- 1주택자의 주택임대소득(기준시가 12억 초과·국외주택 제외)  \n'
#  '- 총수입 2천만원 이하 주택임대소득(2018.12.31.까지 발생분)\n'
#  '\n'
#  '------------------------------------------------\n'
#  '2. 근로·퇴직소득\n'
#  '2.1 군·공공복무  \n'
#  '- 복무 중 병사 급여(대통령령이 정하는 범위)  \n'
#  '- 법률에 따라 동원된 사람이 그 직장에서 받는 급여\n'
#  '\n'
#  '2.2 산재·보상성 급여  \n'
#  '- 산재보험 요양·휴업·장해·간병·유족급여 등  \n'
#  '- 근기법·선원법상 요양·휴업·장해·유족·장의비 등 보상금  \n'
#  '- 산재보험 장의비, 배상·위자성 급여\n'
#  '\n'
#  '2.3 육아·실업급여  \n'
#  '- 고용보험 실업급여·육아휴직급여·출산전후급여 등  \n'
#  '- 공무원·사립학교·별정우체국 육아휴직수당(한도 있음)\n'
#  '\n'
#  '2.4 복리후생성 급여  \n'
#  '- 대통령령이 정하는 복리후생적 성질의 급여\n'
#  '\n'
#  '------------------------------------------------\n'
#  '3. 연금소득\n'
#  '- 공적연금(국민·공무원·군인·사학·별정우체국 등)  \n'
#  '  유족·퇴직유족·퇴역유족·장해·상이·순직유족·직무상유족·위험직무순직유족연금, 장애·장해연금, 연계노령유족연금 등  \n'
#  '- 산재보험 각종 연금  \n'
#  '- 국군포로연금(「국군포로의 송환 및 대우 등에 관한 법률」)\n'
#  '\n'
#  '------------------------------------------------\n'
#  '4. 기타소득\n'
#  '4.1 국가보훈·탈북지원  \n'
#  '- 국가유공자 보훈급여금·학습보조비  \n'
#  '- 북한이탈주민 정착금·보로금 등\n'
#  '\n'
#  '4.2 상금·포상금  \n'
#  '- 「국가보안법」 상금·보로금  \n'
#  '- 「상훈법」 훈장 부상금, 대통령령이 정하는 상금·부상\n'
#  '\n'
#  '4.3 직무발명보상금  \n'
#  '- 퇴직 후 사용자·산학협력단으로부터 받는 보상금(대통령령 한도)  \n'
#  '- 대학 재학 중 산학협력단 보상금\n'
#  '\n'
#  '4.4 문화재 양도소득  \n'
#  '- 국지정문화재(서화·골동품) 양도소득  \n'
#  '- 박물관·미술관에 서화·골동품 양도소득\n'
#  '\n'
#  '4.5 국군포로 위로지원금  \n'
#  '- 「국군포로의 송환 및 대우 등에 관한 법률」에 따른 위로지원금 및 금품\n'
#  '\n'
#  '------------------------------------------------\n'
#  '5. 종교인소득\n'
#  '- 종교관련종사자가 받는 대통령령이 정하는  \n'
#  '  – 학자금  \n'
#  '  – 식사 또는 식사대  \n'
#  '  – 실비변상적 지급액  \n'
#  '- 출산·6세 이하 자녀 보육비(월 20만원 한도)  \n'
#  '- 기획재정부령이 정하는 사택 제공 이익\n'
#  '\n'
#  '------------------------------------------------\n'
#  '6. 공익신탁 이익\n'
#  '- 「공익신탁법」에 따른 공익신탁의 이익\n'
#  '\n'
#  '------------------------------------------------\n'
#  '7. 무상위원 수당\n'
#  '- 법령·조례에 따라 보수를 받지 않는 위원(학술원·예술원 회원 포함)이 받는 수당\n'
#  '\n'
#  '------------------------------------------------\n'
#  '8. 공적연금 일시금\n'
#  '- 「국민연금법」 반환일시금(사망으로 받는 것만) 및 사망일시금\n'
#  '\n'
#  '8.1 공무상 재해 일시금·유족금 등  \n'
#  '- 공무원연금·군인연금·사학연금·별정우체국법 등에서  \n'
#  '  공무상요양비·요양급여·장해일시금·사망보상금·유족일시금·퇴직유족일시금·재해부조금·재난부조금 등\n'
#  '\n'
#  '------------------------------------------------\n'
#  '정리하면, 소득세법은 농축산·임업·어업, 국가보훈·산재보상, 공적연금, 종교인 복지급여, 문화재 양도, 직무발명보상금 등 사회정책적 '
#  '목적이 강한 소득을 대폭 비과세하고 있으며, 각각 “대통령령(또는 기획재정부령)이 정하는 범위”나 “금액 한도”를 반드시 함께 확인해야 '
#  '합니다.')
